# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf

sys.path.append('..')
import deepomics

from deepomics import neuralnetwork as nn
from deepomics import utils, fit

# %% [markdown]
# # load Frey faces dataset

# %%
fname = '../data/frey_rawface.mat'

from scipy.io import loadmat
matfile = loadmat(fname)
all_data = (matfile['ff'] / 255.).T
indices = np.arange(len(all_data))
np.random.shuffle(indices)

# split dataset into train and validation 
X_train = all_data[indices[:1500]]
X_valid = all_data[indices[1500:]]

# place data as a dictionary
train = {'inputs': X_train, 'targets': X_train}
valid = {'inputs': X_valid, 'targets': X_valid}

width = 20
height = 28
input_shape = [None, width*height]
output_shape = [None, width*height]

# %%
def model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'dense',
            'num_units': 128,
            'activation': 'relu',
            #'dropout': 0.1,
            }
    layer3 = {'layer': 'variational_normal',
            'num_units': 30,
            'name': 'Z',
            }
    layer4 = {'layer': 'dense',
            'num_units': 128,
            'activation': 'relu',
            #'dropout': 0.1,
            }
    layer5 = {'layer': 'variational_normal',
            'num_units': output_shape[1],
            'activation': 'sigmoid',
            'name': 'X'
             }
    
    #from tfomics import build_network
    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "elbo_gaussian_gaussian",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "beta1": 0.9, 
                  #"l2": 1e-6,
                  }
    return model_layers, optimization


# get model info
model_layers, optimization = model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization, supervised=False)
nnmodel.inspect_layers()

# compile neural trainer
model_save_path = os.path.join('../results', 'frey')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=model_save_path)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 560)
# layer2: dense_0
# (?, 128)
# layer3: dense_0_bias
# (?, 128)
# layer4: dense_0_active
# (?, 128)
# layer5: Z_mu
# (?, 30)
# layer6: Z_logvar
# (?, 30)
# layer7: Z_sample
# (?, 30)
# layer8: dense_1
# (?, 128)
# layer9: dense_1_bias
# (?, 128)
# layer10: dense_1_active
# (?, 128)
# layer11: X_mu
# (?, 560)
# layer12: X_logvar
# (?, 560)
# layer13: X_sample
# (?, 560)
# layer14: X
# (?, 560)
# ----------------------------------------------------------------------------

# %% [markdown]
# # Start the session

# %%
# initialize session
sess = utils.initialize_session()

# %% [markdown]
# # Train the model with KL-weight annealing  (Starts from an autoencoder and becomes a fully VAE model over time)

# %%
data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, batch_size=128,
                    num_epochs=500, patience=20, verbose=1, shuffle=True)
# Out:
# Epoch 1 out of 500
#   valid loss:		375.17281
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 2 out of 500
#   valid loss:		31.92369
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 3 out of 500
#   valid loss:		-268.32437
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 4 out of 500
#   valid loss:		-419.60052
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 5 out of 500
#   valid loss:		-471.30425
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 6 out of 500
#   valid loss:		-491.19909
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 7 out of 500
#   valid loss:		-505.54077
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 8 out of 500
#   valid loss:		-516.59283
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 9 out of 500
#   valid loss:		-522.14861
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 10 out of 500
#   valid loss:		-533.75604
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 11 out of 500
#   valid loss:		-545.76685
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 12 out of 500
#   valid loss:		-559.60463
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 13 out of 500
#   valid loss:		-575.26642
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 14 out of 500
#   valid loss:		-588.76102
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 15 out of 500
#   valid loss:		-603.30119
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 16 out of 500
#   valid loss:		-618.28784
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 17 out of 500
#   valid loss:		-629.81169
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 18 out of 500
#   valid loss:		-643.29184
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 19 out of 500
#   valid loss:		-657.81599
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 20 out of 500
#   valid loss:		-667.40462
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 21 out of 500
#   valid loss:		-679.64575
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 22 out of 500
#   valid loss:		-695.67316
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 23 out of 500
#   valid loss:		-702.03102
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 24 out of 500
#   valid loss:		-709.72198
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 25 out of 500
#   valid loss:		-720.91139
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 26 out of 500
#   valid loss:		-729.28354
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 27 out of 500
#   valid loss:		-739.80133
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 28 out of 500
#   valid loss:		-733.96939
# Epoch 29 out of 500
#   valid loss:		-751.67403
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 30 out of 500
#   valid loss:		-758.46458
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 31 out of 500
#   valid loss:		-765.12585
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 32 out of 500
#   valid loss:		-771.74574
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 33 out of 500
#   valid loss:		-773.43512
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 34 out of 500
#   valid loss:		-776.50040
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 35 out of 500
#   valid loss:		-787.34502
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 36 out of 500
#   valid loss:		-793.48451
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 37 out of 500
#   valid loss:		-796.68991
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 38 out of 500
#   valid loss:		-798.72218
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 39 out of 500
#   valid loss:		-806.92877
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 40 out of 500
#   valid loss:		-812.90363
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 41 out of 500
#   valid loss:		-818.48679
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 42 out of 500
#   valid loss:		-820.81242
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 43 out of 500
#   valid loss:		-822.60947
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 44 out of 500
#   valid loss:		-822.66396
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 45 out of 500
#   valid loss:		-828.43866
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 46 out of 500
#   valid loss:		-835.52908
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 47 out of 500
#   valid loss:		-836.80728
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 48 out of 500
#   valid loss:		-841.52303
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 49 out of 500
#   valid loss:		-842.20506
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 50 out of 500
#   valid loss:		-849.34734
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 51 out of 500
#   valid loss:		-851.04887
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 52 out of 500
#   valid loss:		-847.05907
# Epoch 53 out of 500
#   valid loss:		-857.61984
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 54 out of 500
#   valid loss:		-857.18851
# Epoch 55 out of 500
#   valid loss:		-852.11382
# Epoch 56 out of 500
#   valid loss:		-862.69879
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 57 out of 500
#   valid loss:		-869.38306
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 58 out of 500
#   valid loss:		-871.62140
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 59 out of 500
#   valid loss:		-864.32729
# Epoch 60 out of 500
#   valid loss:		-871.10532
# Epoch 61 out of 500
#   valid loss:		-879.07109
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 62 out of 500
#   valid loss:		-873.17497
# Epoch 63 out of 500
#   valid loss:		-873.98924
# Epoch 64 out of 500
#   valid loss:		-886.09236
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 65 out of 500
#   valid loss:		-887.27597
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 66 out of 500
#   valid loss:		-897.07910
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 67 out of 500
#   valid loss:		-898.75012
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 68 out of 500
#   valid loss:		-877.42548
# Epoch 69 out of 500
#   valid loss:		-878.17159
# Epoch 70 out of 500
#   valid loss:		-896.30383
# Epoch 71 out of 500
#   valid loss:		-905.74574
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 72 out of 500
#   valid loss:		-905.04936
# Epoch 73 out of 500
#   valid loss:		-910.77583
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 74 out of 500
#   valid loss:		-900.37672
# Epoch 75 out of 500
#   valid loss:		-903.50131
# Epoch 76 out of 500
#   valid loss:		-914.31165
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 77 out of 500
#   valid loss:		-910.62979
# Epoch 78 out of 500
#   valid loss:		-913.62437
# Epoch 79 out of 500
#   valid loss:		-920.72154
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 80 out of 500
#   valid loss:		-919.98805
# Epoch 81 out of 500
#   valid loss:		-919.82349
# Epoch 82 out of 500
#   valid loss:		-924.18111
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 83 out of 500
#   valid loss:		-928.60588
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 84 out of 500
#   valid loss:		-929.56354
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 85 out of 500
#   valid loss:		-928.15698
# Epoch 86 out of 500
#   valid loss:		-914.01604
# Epoch 87 out of 500
#   valid loss:		-927.36156
# Epoch 88 out of 500
#   valid loss:		-935.53983
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 89 out of 500
#   valid loss:		-934.81703
# Epoch 90 out of 500
#   valid loss:		-936.50812
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 91 out of 500
#   valid loss:		-931.82721
# Epoch 92 out of 500
#   valid loss:		-941.64211
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 93 out of 500
#   valid loss:		-947.50343
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 94 out of 500
#   valid loss:		-944.66212
# Epoch 95 out of 500
#   valid loss:		-945.31552
# Epoch 96 out of 500
#   valid loss:		-950.20064
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 97 out of 500
#   valid loss:		-950.19858
# Epoch 98 out of 500
#   valid loss:		-947.34296
# Epoch 99 out of 500
#   valid loss:		-952.52310
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 100 out of 500
#   valid loss:		-957.12927
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 101 out of 500
#   valid loss:		-956.67088
# Epoch 102 out of 500
#   valid loss:		-959.44803
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 103 out of 500
#   valid loss:		-965.44354
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 104 out of 500
#   valid loss:		-967.90036
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 105 out of 500
#   valid loss:		-962.17891
# Epoch 106 out of 500
#   valid loss:		-964.82912
# Epoch 107 out of 500
#   valid loss:		-965.18958
# Epoch 108 out of 500
#   valid loss:		-971.74992
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 109 out of 500
#   valid loss:		-967.34393
# Epoch 110 out of 500
#   valid loss:		-975.57303
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 111 out of 500
#   valid loss:		-970.60373
# Epoch 112 out of 500
#   valid loss:		-972.48695
# Epoch 113 out of 500
#   valid loss:		-972.68481
# Epoch 114 out of 500
#   valid loss:		-979.23524
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 115 out of 500
#   valid loss:		-977.60808
# Epoch 116 out of 500
#   valid loss:		-981.22864
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 117 out of 500
#   valid loss:		-982.63014
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 118 out of 500
#   valid loss:		-976.53102
# Epoch 119 out of 500
#   valid loss:		-982.98929
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 120 out of 500
#   valid loss:		-980.66965
# Epoch 121 out of 500
#   valid loss:		-985.20912
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 122 out of 500
#   valid loss:		-987.25217
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 123 out of 500
#   valid loss:		-984.89682
# Epoch 124 out of 500
#   valid loss:		-989.07626
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 125 out of 500
#   valid loss:		-988.46729
# Epoch 126 out of 500
#   valid loss:		-994.65604
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 127 out of 500
#   valid loss:		-989.57106
# Epoch 128 out of 500
#   valid loss:		-991.05287
# Epoch 129 out of 500
#   valid loss:		-991.56367
# Epoch 130 out of 500
#   valid loss:		-996.66452
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 131 out of 500
#   valid loss:		-996.60405
# Epoch 132 out of 500
#   valid loss:		-990.85425
# Epoch 133 out of 500
#   valid loss:		-992.70059
# Epoch 134 out of 500
#   valid loss:		-997.01585
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 135 out of 500
#   valid loss:		-995.11490
# Epoch 136 out of 500
#   valid loss:		-991.32639
# Epoch 137 out of 500
#   valid loss:		-999.82779
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 138 out of 500
#   valid loss:		-1005.77124
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 139 out of 500
#   valid loss:		-1004.36876
# Epoch 140 out of 500
#   valid loss:		-1004.51463
# Epoch 141 out of 500
#   valid loss:		-1005.40620
# Epoch 142 out of 500
#   valid loss:		-989.80392
# Epoch 143 out of 500
#   valid loss:		-992.38995
# Epoch 144 out of 500
#   valid loss:		-1004.18727
# Epoch 145 out of 500
#   valid loss:		-1007.46661
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 146 out of 500
#   valid loss:		-1009.89418
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 147 out of 500
#   valid loss:		-1006.82407
# Epoch 148 out of 500
#   valid loss:		-1010.30673
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 149 out of 500
#   valid loss:		-1015.05344
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 150 out of 500
#   valid loss:		-1008.56497
# Epoch 151 out of 500
#   valid loss:		-1013.80858
# Epoch 152 out of 500
#   valid loss:		-1009.44913
# Epoch 153 out of 500
#   valid loss:		-1014.15704
# Epoch 154 out of 500
#   valid loss:		-1009.82719
# Epoch 155 out of 500
#   valid loss:		-1011.95749
# Epoch 156 out of 500
#   valid loss:		-1015.15543
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 157 out of 500
#   valid loss:		-1012.45508
# Epoch 158 out of 500
#   valid loss:		-999.26685
# Epoch 159 out of 500
#   valid loss:		-1014.10913
# Epoch 160 out of 500
#   valid loss:		-1014.59641
# Epoch 161 out of 500
#   valid loss:		-1002.74269
# Epoch 162 out of 500
#   valid loss:		-1008.59261
# Epoch 163 out of 500
#   valid loss:		-1018.33682
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 164 out of 500
#   valid loss:		-1020.33887
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 165 out of 500
#   valid loss:		-1015.65021
# Epoch 166 out of 500
#   valid loss:		-1023.64700
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 167 out of 500
#   valid loss:		-1017.31924
# Epoch 168 out of 500
#   valid loss:		-1023.02229
# Epoch 169 out of 500
#   valid loss:		-1023.34679
# Epoch 170 out of 500
#   valid loss:		-1025.28130
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 171 out of 500
#   valid loss:		-1028.07047
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 172 out of 500
#   valid loss:		-1026.07014
# Epoch 173 out of 500
#   valid loss:		-1027.34203
# Epoch 174 out of 500
#   valid loss:		-1029.75386
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 175 out of 500
#   valid loss:		-1030.40663
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 176 out of 500
#   valid loss:		-1030.19635
# Epoch 177 out of 500
#   valid loss:		-1021.46915
# Epoch 178 out of 500
#   valid loss:		-1029.16414
# Epoch 179 out of 500
#   valid loss:		-1025.10684
# Epoch 180 out of 500
#   valid loss:		-1030.57695
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 181 out of 500
#   valid loss:		-1032.05508
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 182 out of 500
#   valid loss:		-1036.13348
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 183 out of 500
#   valid loss:		-1033.06891
# Epoch 184 out of 500
#   valid loss:		-1036.00291
# Epoch 185 out of 500
#   valid loss:		-1033.95062
# Epoch 186 out of 500
#   valid loss:		-1032.89517
# Epoch 187 out of 500
#   valid loss:		-1034.63789
# Epoch 188 out of 500
#   valid loss:		-1036.98344
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 189 out of 500
#   valid loss:		-1035.32378
# Epoch 190 out of 500
#   valid loss:		-1038.79944
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 191 out of 500
#   valid loss:		-1033.46288
# Epoch 192 out of 500
#   valid loss:		-1036.61719
# Epoch 193 out of 500
#   valid loss:		-1043.45737
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 194 out of 500
#   valid loss:		-1039.08585
# Epoch 195 out of 500
#   valid loss:		-1037.57887
# Epoch 196 out of 500
#   valid loss:		-1042.44577
# Epoch 197 out of 500
#   valid loss:		-1037.95306
# Epoch 198 out of 500
#   valid loss:		-1031.05591
# Epoch 199 out of 500
#   valid loss:		-1043.03394
# Epoch 200 out of 500
#   valid loss:		-1043.69073
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 201 out of 500
#   valid loss:		-1038.44635
# Epoch 202 out of 500
#   valid loss:		-1041.75146
# Epoch 203 out of 500
#   valid loss:		-1043.07401
# Epoch 204 out of 500
#   valid loss:		-1043.03683
# Epoch 205 out of 500
#   valid loss:		-1041.91843
# Epoch 206 out of 500
#   valid loss:		-1051.62125
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 207 out of 500
#   valid loss:		-1042.56415
# Epoch 208 out of 500
#   valid loss:		-1048.24246
# Epoch 209 out of 500
#   valid loss:		-1049.87131
# Epoch 210 out of 500
#   valid loss:		-1043.96722
# Epoch 211 out of 500
#   valid loss:		-1049.55975
# Epoch 212 out of 500
#   valid loss:		-1051.52118
# Epoch 213 out of 500
#   valid loss:		-1047.35919
# Epoch 214 out of 500
#   valid loss:		-1046.93530
# Epoch 215 out of 500
#   valid loss:		-1050.77792
# Epoch 216 out of 500
#   valid loss:		-1044.52527
# Epoch 217 out of 500
#   valid loss:		-1049.14767
# Epoch 218 out of 500
#   valid loss:		-1054.86041
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 219 out of 500
#   valid loss:		-1058.38242
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 220 out of 500
#   valid loss:		-1051.30560
# Epoch 221 out of 500
#   valid loss:		-1055.62775
# Epoch 222 out of 500
#   valid loss:		-1057.92252
# Epoch 223 out of 500
#   valid loss:		-1058.72079
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 224 out of 500
#   valid loss:		-1055.43951
# Epoch 225 out of 500
#   valid loss:		-1060.39294
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 226 out of 500
#   valid loss:		-1058.78925
# Epoch 227 out of 500
#   valid loss:		-1062.38022
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 228 out of 500
#   valid loss:		-1058.35974
# Epoch 229 out of 500
#   valid loss:		-1054.15115
# Epoch 230 out of 500
#   valid loss:		-1058.90009
# Epoch 231 out of 500
#   valid loss:		-1058.99399
# Epoch 232 out of 500
#   valid loss:		-1058.74878
# Epoch 233 out of 500
#   valid loss:		-1060.24573
# Epoch 234 out of 500
#   valid loss:		-1065.27380
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 235 out of 500
#   valid loss:		-1060.54904
# Epoch 236 out of 500
#   valid loss:		-1064.94821
# Epoch 237 out of 500
#   valid loss:		-1064.51349
# Epoch 238 out of 500
#   valid loss:		-1058.21048
# Epoch 239 out of 500
#   valid loss:		-1052.53156
# Epoch 240 out of 500
#   valid loss:		-1057.47333
# Epoch 241 out of 500
#   valid loss:		-1063.97876
# Epoch 242 out of 500
#   valid loss:		-1062.32068
# Epoch 243 out of 500
#   valid loss:		-1064.82571
# Epoch 244 out of 500
#   valid loss:		-1067.58118
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 245 out of 500
#   valid loss:		-1058.52429
# Epoch 246 out of 500
#   valid loss:		-1062.43097
# Epoch 247 out of 500
#   valid loss:		-1064.41464
# Epoch 248 out of 500
#   valid loss:		-1068.05719
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 249 out of 500
#   valid loss:		-1070.87952
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 250 out of 500
#   valid loss:		-1071.21277
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 251 out of 500
#   valid loss:		-1065.91028
# Epoch 252 out of 500
#   valid loss:		-1061.90616
# Epoch 253 out of 500
#   valid loss:		-1061.73322
# Epoch 254 out of 500
#   valid loss:		-1068.95071
# Epoch 255 out of 500
#   valid loss:		-1073.33301
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 256 out of 500
#   valid loss:		-1068.08923
# Epoch 257 out of 500
#   valid loss:		-1071.15500
# Epoch 258 out of 500
#   valid loss:		-1076.15756
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 259 out of 500
#   valid loss:		-1071.91364
# Epoch 260 out of 500
#   valid loss:		-1072.81171
# Epoch 261 out of 500
#   valid loss:		-1076.36075
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 262 out of 500
#   valid loss:		-1074.62823
# Epoch 263 out of 500
#   valid loss:		-1075.49219
# Epoch 264 out of 500
#   valid loss:		-1075.23767
# Epoch 265 out of 500
#   valid loss:		-1079.53967
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 266 out of 500
#   valid loss:		-1080.86316
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 267 out of 500
#   valid loss:		-1079.72525
# Epoch 268 out of 500
#   valid loss:		-1079.18674
# Epoch 269 out of 500
#   valid loss:		-1075.73596
# Epoch 270 out of 500
#   valid loss:		-1074.74915
# Epoch 271 out of 500
#   valid loss:		-1072.53888
# Epoch 272 out of 500
#   valid loss:		-1081.52255
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 273 out of 500
#   valid loss:		-1073.54959
# Epoch 274 out of 500
#   valid loss:		-1079.80893
# Epoch 275 out of 500
#   valid loss:		-1079.24301
# Epoch 276 out of 500
#   valid loss:		-1083.93155
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 277 out of 500
#   valid loss:		-1080.62573
# Epoch 278 out of 500
#   valid loss:		-1073.59982
# Epoch 279 out of 500
#   valid loss:		-1076.89581
# Epoch 280 out of 500
#   valid loss:		-1078.72104
# Epoch 281 out of 500
#   valid loss:		-1071.76660
# Epoch 282 out of 500
#   valid loss:		-1080.06738
# Epoch 283 out of 500
#   valid loss:		-1085.69949
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 284 out of 500
#   valid loss:		-1080.58798
# Epoch 285 out of 500
#   valid loss:		-1082.43900
# Epoch 286 out of 500
#   valid loss:		-1080.02820
# Epoch 287 out of 500
#   valid loss:		-1086.14243
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 288 out of 500
#   valid loss:		-1086.66620
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 289 out of 500
#   valid loss:		-1086.92407
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 290 out of 500
#   valid loss:		-1083.22168
# Epoch 291 out of 500
#   valid loss:		-1084.63986
# Epoch 292 out of 500
#   valid loss:		-1085.22501
# Epoch 293 out of 500
#   valid loss:		-1086.47241
# Epoch 294 out of 500
#   valid loss:		-1084.02325
# Epoch 295 out of 500
#   valid loss:		-1072.93274
# Epoch 296 out of 500
#   valid loss:		-1082.17853
# Epoch 297 out of 500
#   valid loss:		-1081.47620
# Epoch 298 out of 500
#   valid loss:		-1089.30710
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 299 out of 500
#   valid loss:		-1080.93054
# Epoch 300 out of 500
#   valid loss:		-1085.73383
# Epoch 301 out of 500
#   valid loss:		-1087.37280
# Epoch 302 out of 500
#   valid loss:		-1089.27216
# Epoch 303 out of 500
#   valid loss:		-1086.54971
# Epoch 304 out of 500
#   valid loss:		-1089.24994
# Epoch 305 out of 500
#   valid loss:		-1089.36691
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 306 out of 500
#   valid loss:		-1092.50400
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 307 out of 500
#   valid loss:		-1092.42807
# Epoch 308 out of 500
#   valid loss:		-1092.50876
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 309 out of 500
#   valid loss:		-1093.30252
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 310 out of 500
#   valid loss:		-1085.26068
# Epoch 311 out of 500
#   valid loss:		-1090.09592
# Epoch 312 out of 500
#   valid loss:		-1091.42798
# Epoch 313 out of 500
#   valid loss:		-1090.79010
# Epoch 314 out of 500
#   valid loss:		-1091.12524
# Epoch 315 out of 500
#   valid loss:		-1095.61945
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 316 out of 500
#   valid loss:		-1091.94943
# Epoch 317 out of 500
#   valid loss:		-1089.06094
# Epoch 318 out of 500
#   valid loss:		-1094.96503
# Epoch 319 out of 500
#   valid loss:		-1085.72858
# Epoch 320 out of 500
#   valid loss:		-1094.30325
# Epoch 321 out of 500
#   valid loss:		-1093.84775
# Epoch 322 out of 500
#   valid loss:		-1085.42108
# Epoch 323 out of 500
#   valid loss:		-1069.23761
# Epoch 324 out of 500
#   valid loss:		-1088.37561
# Epoch 325 out of 500
#   valid loss:		-1089.52002
# Epoch 326 out of 500
#   valid loss:		-1089.34521
# Epoch 327 out of 500
#   valid loss:		-1095.80502
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 328 out of 500
#   valid loss:		-1096.83328
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 329 out of 500
#   valid loss:		-1095.69836
# Epoch 330 out of 500
#   valid loss:		-1095.79062
# Epoch 331 out of 500
#   valid loss:		-1094.47226
# Epoch 332 out of 500
#   valid loss:		-1095.37625
# Epoch 333 out of 500
#   valid loss:		-1094.05069
# Epoch 334 out of 500
#   valid loss:		-1088.56387
# Epoch 335 out of 500
#   valid loss:		-1094.49652
# Epoch 336 out of 500
#   valid loss:		-1100.90741
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 337 out of 500
#   valid loss:		-1099.40244
# Epoch 338 out of 500
#   valid loss:		-1092.21500
# Epoch 339 out of 500
#   valid loss:		-1091.89087
# Epoch 340 out of 500
#   valid loss:		-1095.24271
# Epoch 341 out of 500
#   valid loss:		-1075.36755
# Epoch 342 out of 500
#   valid loss:		-1081.25192
# Epoch 343 out of 500
#   valid loss:		-1088.47238
# Epoch 344 out of 500
#   valid loss:		-1096.96539
# Epoch 345 out of 500
#   valid loss:		-1098.95450
# Epoch 346 out of 500
#   valid loss:		-1097.27490
# Epoch 347 out of 500
#   valid loss:		-1101.21988
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 348 out of 500
#   valid loss:		-1103.76917
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 349 out of 500
#   valid loss:		-1098.67163
# Epoch 350 out of 500
#   valid loss:		-1099.88220
# Epoch 351 out of 500
#   valid loss:		-1095.05350
# Epoch 352 out of 500
#   valid loss:		-1095.91876
# Epoch 353 out of 500
#   valid loss:		-1096.37921
# Epoch 354 out of 500
#   valid loss:		-1099.11099
# Epoch 355 out of 500
#   valid loss:		-1098.90375
# Epoch 356 out of 500
#   valid loss:		-1098.15167
# Epoch 357 out of 500
#   valid loss:		-1102.98550
# Epoch 358 out of 500
#   valid loss:		-1104.11661
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 359 out of 500
#   valid loss:		-1101.11539
# Epoch 360 out of 500
#   valid loss:		-1102.65210
# Epoch 361 out of 500
#   valid loss:		-1098.40082
# Epoch 362 out of 500
#   valid loss:		-1094.29407
# Epoch 363 out of 500
#   valid loss:		-1101.25565
# Epoch 364 out of 500
#   valid loss:		-1099.13412
# Epoch 365 out of 500
#   valid loss:		-1097.37509
# Epoch 366 out of 500
#   valid loss:		-1106.31900
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 367 out of 500
#   valid loss:		-1105.51843
# Epoch 368 out of 500
#   valid loss:		-1102.83981
# Epoch 369 out of 500
#   valid loss:		-1103.39404
# Epoch 370 out of 500
#   valid loss:		-1096.33191
# Epoch 371 out of 500
#   valid loss:		-1099.54172
# Epoch 372 out of 500
#   valid loss:		-1104.00476
# Epoch 373 out of 500
#   valid loss:		-1097.96039
# Epoch 374 out of 500
#   valid loss:		-1104.05234
# Epoch 375 out of 500
#   valid loss:		-1106.75516
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 376 out of 500
#   valid loss:		-1106.60629
# Epoch 377 out of 500
#   valid loss:		-1105.17242
# Epoch 378 out of 500
#   valid loss:		-1105.48953
# Epoch 379 out of 500
#   valid loss:		-1103.11398
# Epoch 380 out of 500
#   valid loss:		-1104.91269
# Epoch 381 out of 500
#   valid loss:		-1106.96542
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 382 out of 500
#   valid loss:		-1109.37634
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 383 out of 500
#   valid loss:		-1099.90811
# Epoch 384 out of 500
#   valid loss:		-1105.96149
# Epoch 385 out of 500
#   valid loss:		-1108.64304
# Epoch 386 out of 500
#   valid loss:		-1107.31134
# Epoch 387 out of 500
#   valid loss:		-1104.21796
# Epoch 388 out of 500
#   valid loss:		-1109.77786
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 389 out of 500
#   valid loss:		-1106.51108
# Epoch 390 out of 500
#   valid loss:		-1102.11517
# Epoch 391 out of 500
#   valid loss:		-1106.23422
# Epoch 392 out of 500
#   valid loss:		-1104.08383
# Epoch 393 out of 500
#   valid loss:		-1101.36127
# Epoch 394 out of 500
#   valid loss:		-1099.14642
# Epoch 395 out of 500
#   valid loss:		-1105.04837
# Epoch 396 out of 500
#   valid loss:		-1108.97064
# Epoch 397 out of 500
#   valid loss:		-1107.74918
# Epoch 398 out of 500
#   valid loss:		-1105.79068
# Epoch 399 out of 500
#   valid loss:		-1110.57550
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 400 out of 500
#   valid loss:		-1104.81583
# Epoch 401 out of 500
#   valid loss:		-1106.21524
# Epoch 402 out of 500
#   valid loss:		-1112.33295
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 403 out of 500
#   valid loss:		-1107.31482
# Epoch 404 out of 500
#   valid loss:		-1112.11514
# Epoch 405 out of 500
#   valid loss:		-1105.25525
# Epoch 406 out of 500
#   valid loss:		-1109.99338
# Epoch 407 out of 500
#   valid loss:		-1097.27042
# Epoch 408 out of 500
#   valid loss:		-1098.90274
# Epoch 409 out of 500
#   valid loss:		-1112.37216
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 410 out of 500
#   valid loss:		-1109.31485
# Epoch 411 out of 500
#   valid loss:		-1113.63718
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 412 out of 500
#   valid loss:		-1108.09766
# Epoch 413 out of 500
#   valid loss:		-1093.39340
# Epoch 414 out of 500
#   valid loss:		-1112.36356
# Epoch 415 out of 500
#   valid loss:		-1114.78915
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 416 out of 500
#   valid loss:		-1095.00006
# Epoch 417 out of 500
#   valid loss:		-1110.63483
# Epoch 418 out of 500
#   valid loss:		-1112.82095
# Epoch 419 out of 500
#   valid loss:		-1113.06735
# Epoch 420 out of 500
#   valid loss:		-1110.88684
# Epoch 421 out of 500
#   valid loss:		-1115.29907
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 422 out of 500
#   valid loss:		-1114.78302
# Epoch 423 out of 500
#   valid loss:		-1113.30307
# Epoch 424 out of 500
#   valid loss:		-1115.83762
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 425 out of 500
#   valid loss:		-1114.16568
# Epoch 426 out of 500
#   valid loss:		-1108.27121
# Epoch 427 out of 500
#   valid loss:		-1088.89951
# Epoch 428 out of 500
#   valid loss:		-1109.78583
# Epoch 429 out of 500
#   valid loss:		-1114.76852
# Epoch 430 out of 500
#   valid loss:		-1110.14954
# Epoch 431 out of 500
#   valid loss:		-1118.68585
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 432 out of 500
#   valid loss:		-1119.76923
#   lower cross-validation found
#   saving model to:  ../results/frey_best.ckpt
# Epoch 433 out of 500
#   valid loss:		-1116.07895
# Epoch 434 out of 500
#   valid loss:		-1113.68402
# Epoch 435 out of 500
#   valid loss:		-1113.01727
# Epoch 436 out of 500
#   valid loss:		-1108.21661
# Epoch 437 out of 500
#   valid loss:		-1118.17969
# Epoch 438 out of 500
#   valid loss:		-1117.44287
# Epoch 439 out of 500
#   valid loss:		-1117.91434
# Epoch 440 out of 500
#   valid loss:		-1110.96106
# Epoch 441 out of 500
#   valid loss:		-1110.30737
# Epoch 442 out of 500
#   valid loss:		-1114.99792
# Epoch 443 out of 500
#   valid loss:		-1119.67148
# Epoch 444 out of 500
#   valid loss:		-1114.86972
# Epoch 445 out of 500
#   valid loss:		-1112.52649
# Epoch 446 out of 500
#   valid loss:		-1118.25494
# Epoch 447 out of 500
#   valid loss:		-1118.49814
# Epoch 448 out of 500
#   valid loss:		-1117.38052
# Epoch 449 out of 500
#   valid loss:		-1110.15536
# Epoch 450 out of 500
#   valid loss:		-1118.37720
# Epoch 451 out of 500
#   valid loss:		-1114.21817
# Epoch 452 out of 500
#   valid loss:		-1114.95853
# Patience ran out... Early stopping.

# %% [markdown]
# # Visualize samples about the latent space mapped by the original image

# %%
num_grid = 10
shuffle = np.random.permutation(X_train.shape[0])
X_data = X_train[shuffle[:num_grid*num_grid]]

samples = nntrainer.get_activations(sess, {'inputs': X_data}, layer='X')

fig = plt.figure()
ax = plt.subplot(1,2,1);
ax.imshow((X_data.reshape(num_grid, num_grid, 28, 20)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*20)), cmap='gray')
ax.axis('off')
ax = plt.subplot(1,2,2);
ax.imshow((samples.reshape(num_grid, num_grid, 28, 20)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*20)), cmap='gray')
ax.axis('off')
fig.set_size_inches(15,15)

# %% [markdown]
# # visualize the latent space learned by the VAE

# %%
# extract latent space for training data
Z = nntrainer.get_activations(sess, {'inputs': X_train}, layer='Z_mu')

# perform PCA on latent space
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
Z_reduce = pca.fit_transform(Z)

# plot reduced latent space
fig = plt.figure()
plt.scatter(Z_reduce[:,0], Z_reduce[:,1], alpha=0.2)
